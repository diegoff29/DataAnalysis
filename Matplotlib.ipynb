# %%
import matplotlib

# %%
import matplotlib.pyplot as plt
input_values=[1,2,3,4,5]
squares=[1,4,9,16,25]
plt.plot(input_values,squares,linewidth=5)
plt.title("Square Numbers",fontsize=24)
plt.xlabel("Value",fontsize=14)
plt.ylabel("Square of Value",fontsize=14)
plt.tick_params(axis="both",labelsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(2,4,s=200)
plt.title("Square Numbers",fontsize=24)
plt.xlabel("Value",fontsize=14)
plt.ylabel("Square of Value",fontsize=14)
plt.tick_params(axis="both",which="major",labelsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
x_values=[1,2,3,4,5]
y_values=[1,4,9,16,25]
plt.scatter(x_values,y_values,s=100)
plt.show()

# %%
import matplotlib.pyplot as plt
x_values=[x for x in range(1,1001)]
y_values=[x**2 for x in x_values]
plt.scatter(x_values,y_values,c="red",edgecolor="none",s=40)
plt.title("Square Numbers",fontsize=24)
plt.xlabel("Value",fontsize=14)
plt.ylabel("Square of Value",fontsize=14)
plt.tick_params(axis="both",which="major",labelsize=14)
plt.axis([0,1100,0,1100000])
plt.show()

# %%
import matplotlib.pyplot as plt
x_values=[x for x in range(1,1001)]
y_values=[x**2 for x in x_values]
plt.scatter(x_values,y_values,c=y_values,cmap=plt.cm.Blues,edgecolor="none",s=40)
plt.title("Square Numbers",fontsize=24)
plt.xlabel("Value",fontsize=14)
plt.ylabel("Square of Value",fontsize=14)
plt.tick_params(axis="both",which="major",labelsize=14)
plt.axis([0,1100,0,1100000])
plt.savefig("squares_plot.png",bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
x_values=[x for x in range(0,5000)]
y_values=[x**3 for x in x_values]
plt.scatter(x_values,y_values,c=y_values,cmap=plt.cm.Greens,edgecolor="none",s=40)
plt.title("Cube Numbers",fontsize=24)
plt.xlabel("Value",fontsize=14)
plt.ylabel("Cube of Value",fontsize=14)
plt.tick_params(axis="both",which="major",labelsize=14)
plt.show()

# %%
from random import choice
import matplotlib.pyplot as plt
class RandomWalk():
    def __init__(self,num_points=5000):
        self.num_points=num_points
        self.xvalues=[0]
        self.yvalues=[0]
    def fill_walk(self):
        while (len(self.xvalues)<self.num_points):
            xdirection=choice([-1,1])
            ydirection=choice([-1,1])
            xmagnitude=choice([x for x in range(0,4)])
            ymagnitude=choice([x for x in range(0,4)])
            xstep=xdirection*xmagnitude
            ystep=ydirection*ymagnitude
            if xstep==ystep==0:
                continue
            new_stepx=self.xvalues[-1] + xstep
            new_stepy=self.yvalues[-1] + ystep
            self.xvalues.append(new_stepx)
            self.yvalues.append(new_stepy)
rw=RandomWalk()
rw.fill_walk()
order=list(range(rw.num_points))
plt.scatter(rw.xvalues,rw.yvalues,c=order,cmap=plt.cm.Oranges,s=40)
plt.scatter(0,0,c="green",s=100)
plt.scatter(rw.xvalues[-1],rw.yvalues[-1],c="red",s=100)
plt.axes().get_xaxis().set_visible(False)
plt.axes().get_yaxis().set_visible(False)
plt.show()
# Out:
# <ipython-input-30-902f349c97d1>:28: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().get_xaxis().set_visible(False)
# <ipython-input-30-902f349c97d1>:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().get_yaxis().set_visible(False)

# %%
import matplotlib.pyplot as plt
class RandomWalk():
    def __init__(self,num_points=5000):
        self.num_points=num_points
        self.xvalues=[0]
        self.yvalues=[0]
    def fill_walk(self):
        while (len(self.xvalues)<self.num_points):
            xdirection=choice([-1,1])
            ydirection=choice([-1,1])
            xmagnitude=choice([x for x in range(0,4)])
            ymagnitude=choice([x for x in range(0,4)])
            xstep=xdirection*xmagnitude
            ystep=ydirection*ymagnitude
            if xstep==ystep==0:
                continue
            new_stepx=self.xvalues[-1] + xstep
            new_stepy=self.yvalues[-1] + ystep
            self.xvalues.append(new_stepx)
            self.yvalues.append(new_stepy)
rw=RandomWalk()
rw.fill_walk()
order=list(range(rw.num_points))
plt.plot(rw.xvalues,rw.yvalues,c="yellow",linewidth=2)
plt.scatter(0,0,c="green",s=200)
plt.scatter(rw.xvalues[-1],rw.yvalues[-1],c="red",s=200)
plt.axes().get_xaxis().set_visible(False)
plt.axes().get_yaxis().set_visible(False)
plt.show()
# Out:
# <ipython-input-34-d1550e1db8e1>:27: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().get_xaxis().set_visible(False)
# <ipython-input-34-d1550e1db8e1>:28: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().get_yaxis().set_visible(False)

# %%
from random import choice
import matplotlib.pyplot as plt
class RandomWalk():
    def __init__(self,num_points=5000):
        self.num_points=num_points
        self.xvalues=[0]
        self.yvalues=[0]
    def get_step(self):
        direction=choice([-1,1])
        magnitude=choice([x for x in range(0,4)])
        step=direction*magnitude
        return step
    def fill_walk(self):
        while (len(self.xvalues)<self.num_points):
            xstep=self.get_step()
            ystep=self.get_step()
            if xstep==ystep==0:
                continue
            new_stepx=self.xvalues[-1] + xstep
            new_stepy=self.yvalues[-1] + ystep
            self.xvalues.append(new_stepx)
            self.yvalues.append(new_stepy)
rw=RandomWalk()
rw.fill_walk()
order=list(range(rw.num_points))
plt.scatter(rw.xvalues,rw.yvalues,c=order,cmap=plt.cm.Oranges,s=40)
plt.scatter(0,0,c="green",s=100)
plt.scatter(rw.xvalues[-1],rw.yvalues[-1],c="red",s=100)
plt.axes().get_xaxis().set_visible(False)
plt.axes().get_yaxis().set_visible(False)
plt.show()
# Out:
# <ipython-input-37-b5b3c1e86ce8>:29: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().get_xaxis().set_visible(False)
# <ipython-input-37-b5b3c1e86ce8>:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().get_yaxis().set_visible(False)

# %%
from random import *
import pygal
rolls=1000
class Die():
    def __init__(self,sides=6):
        self.sides=sides
    def roll(self):
        result=randint(1,self.sides)
        return result
die=Die()
Numbers=[]
for x in range(rolls):
    points=die.roll()
    Numbers.append(points)
frequencies=[]
for n in range(1,die.sides+1):
    Appeareances=Numbers.count(n)
    frequencies.append(Appeareances)
print(frequencies)
hist=pygal.Bar()
hist.title="Results on rolling six-sided dice 1000 times"
hist.labels=[x for x in range(1,die.sides+1)]
hist.x_label="Dice number"
hist.y_label="Frequency"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-01ba0ed1a6dd> in <module>
#       1 from random import *
# ----> 2 import pygal
#       3 rolls=1000
#       4 class Die():
#       5     def __init__(self,sides=6):
#
# ModuleNotFoundError: No module named 'pygal'
